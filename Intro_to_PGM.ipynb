# %% [markdown]
# **Preparation**
#
# This notebook has to be run on google Colab
#
# The following section is only about training and putting everthing in place.
#
# We will provide you with save.zip and cifar-10-python.tar.gz, so there is no need to run the training for the three models

# %%
# !git clone https://github.com/Athirhama/my_deepBayes
# Out:
# Cloning into 'my_deepBayes'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 176 (delta 66), reused 176 (delta 66), pack-reused 0 (from 0)
# Receiving objects: 100% (176/176), 285.86 KiB | 1.50 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
cd /content/my_deepBayes/
# Out:
# /content/my_deepBayes

# %%
mkdir cifar_data

# %%
mkdir save

# %%
cd /content
# Out:
# /content

# %%
# !mv save.zip /content/my_deepBayes/save

# %%
# !mv cifar-10-python.tar.gz /content/my_deepBayes/cifar_data/

# %%
# !cd /content/my_deepBayes/cifar_data/&& tar -xvzf cifar-10-python.tar.gz
# Out:
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1

# %%
# !cd /content/my_deepBayes/save/&& unzip save.zip
# Out:
# Archive:  save.zip
#    creating: plane_frog_conv_vae_B_128/
#    creating: plane_frog_conv_vae_C_128/
#    creating: plane_frog_conv_vae_F_128/
#   inflating: plane_frog_conv_vae_B_128/checkpoint_0.pkl
#   inflating: plane_frog_conv_vae_C_128/checkpoint_0.pkl
#   inflating: plane_frog_conv_vae_F_128/checkpoint_0.pkl

# %%
cd /content/my_deepBayes/
# Out:
# /content/my_deepBayes

# %% [markdown]
# # **Train models**

# %% [markdown]
# Train the GFZ model

# %%
# !python vae_cifar_binary.py F
# Out:
# 2025-12-10 09:29:38.592589: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765358978.625824    1804 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765358978.635453    1804 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765358978.659494    1804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765358978.659530    1804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765358978.659538    1804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765358978.659544    1804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-10 09:29:38.665311: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# decoder shared Conv Net of size [(4, 4, 256), (8, 8, 128), (16, 16, 64), (32, 32, 3)]
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# encoder shared Conv net  network architecture: [(16, 16, 64), (8, 8, 128), (4, 4, 256)] [1000]
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/dispatch.py:1260: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# I0000 00:00:1765358987.582851    1804 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# create path save/plane_frog_conv_vae_F_128/
# training from scratch
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/tf_should_use.py:288: initialize_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.variables_initializer` instead.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765358987.605337    1804 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# training for 10 epochs with lr=0.00005, beta=1.00
# I0000 00:00:1765358988.466987    1862 cuda_dnn.cc:529] Loaded cuDNN version 91002
# Iter 1, logp(x|y)=-192.86, time=5.64
# Iter 2, logp(x|y)=-170.68, time=2.64
# Iter 3, logp(x|y)=-163.31, time=2.64
# Iter 4, logp(x|y)=-149.02, time=2.67
# Iter 5, logp(x|y)=-122.50, time=2.73
# Iter 6, logp(x|y)=-116.01, time=2.68
# Iter 7, logp(x|y)=-112.12, time=2.66
# Iter 8, logp(x|y)=-109.85, time=2.66
# Iter 9, logp(x|y)=-107.29, time=2.68
# Iter 10, logp(x|y)=-105.44, time=2.74
# test data approx Bayes classifier acc=67.05, bound=-103.07, time=3.64, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-102.48, time=2.68
# Iter 2, logp(x|y)=-100.09, time=2.71
# Iter 3, logp(x|y)=-97.81, time=2.81
# Iter 4, logp(x|y)=-95.96, time=2.72
# Iter 5, logp(x|y)=-95.11, time=2.69
# Iter 6, logp(x|y)=-94.29, time=2.70
# Iter 7, logp(x|y)=-93.46, time=2.82
# Iter 8, logp(x|y)=-92.69, time=2.73
# Iter 9, logp(x|y)=-91.81, time=2.70
# Iter 10, logp(x|y)=-90.60, time=2.70
# test data approx Bayes classifier acc=74.80, bound=-89.43, time=1.63, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-88.15, time=2.84
# Iter 2, logp(x|y)=-85.59, time=2.73
# Iter 3, logp(x|y)=-83.96, time=2.73
# Iter 4, logp(x|y)=-82.92, time=2.74
# Iter 5, logp(x|y)=-81.93, time=2.80
# Iter 6, logp(x|y)=-81.33, time=2.80
# Iter 7, logp(x|y)=-80.65, time=2.75
# Iter 8, logp(x|y)=-80.15, time=2.76
# Iter 9, logp(x|y)=-79.63, time=2.78
# Iter 10, logp(x|y)=-79.31, time=2.82
# test data approx Bayes classifier acc=78.30, bound=-78.71, time=1.64, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-79.17, time=2.79
# Iter 2, logp(x|y)=-78.98, time=2.79
# Iter 3, logp(x|y)=-78.63, time=2.85
# Iter 4, logp(x|y)=-78.45, time=2.85
# Iter 5, logp(x|y)=-78.25, time=2.80
# Iter 6, logp(x|y)=-77.91, time=2.79
# Iter 7, logp(x|y)=-77.57, time=2.81
# Iter 8, logp(x|y)=-77.31, time=2.85
# Iter 9, logp(x|y)=-76.88, time=2.80
# Iter 10, logp(x|y)=-76.63, time=2.81
# test data approx Bayes classifier acc=82.15, bound=-75.77, time=1.67, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-76.35, time=2.84
# Iter 2, logp(x|y)=-75.94, time=2.82
# Iter 3, logp(x|y)=-75.51, time=2.79
# Iter 4, logp(x|y)=-75.32, time=2.78
# Iter 5, logp(x|y)=-74.93, time=2.82
# Iter 6, logp(x|y)=-74.63, time=2.91
# Iter 7, logp(x|y)=-74.58, time=2.80
# Iter 8, logp(x|y)=-74.30, time=2.80
# Iter 9, logp(x|y)=-74.14, time=2.78
# Iter 10, logp(x|y)=-74.05, time=2.88
# test data approx Bayes classifier acc=85.85, bound=-73.22, time=1.67, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-73.97, time=2.80
# Iter 2, logp(x|y)=-73.84, time=2.80
# Iter 3, logp(x|y)=-73.80, time=2.82
# Iter 4, logp(x|y)=-73.66, time=2.88
# Iter 5, logp(x|y)=-73.64, time=2.81
# Iter 6, logp(x|y)=-73.46, time=2.82
# Iter 7, logp(x|y)=-73.54, time=2.81
# Iter 8, logp(x|y)=-73.30, time=2.91
# Iter 9, logp(x|y)=-73.13, time=2.85
# Iter 10, logp(x|y)=-73.13, time=2.88
# test data approx Bayes classifier acc=86.50, bound=-72.29, time=1.73, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-73.07, time=2.90
# Iter 2, logp(x|y)=-72.99, time=2.92
# Iter 3, logp(x|y)=-72.82, time=2.89
# Iter 4, logp(x|y)=-72.77, time=2.90
# Iter 5, logp(x|y)=-72.66, time=2.92
# Iter 6, logp(x|y)=-72.69, time=3.00
# Iter 7, logp(x|y)=-72.71, time=2.92
# Iter 8, logp(x|y)=-72.55, time=2.93
# Iter 9, logp(x|y)=-72.49, time=2.93
# Iter 10, logp(x|y)=-72.50, time=3.00
# test data approx Bayes classifier acc=87.15, bound=-71.76, time=1.75, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-72.27, time=2.89
# Iter 2, logp(x|y)=-72.29, time=2.88
# Iter 3, logp(x|y)=-72.29, time=2.97
# Iter 4, logp(x|y)=-72.11, time=2.94
# Iter 5, logp(x|y)=-72.04, time=2.88
# Iter 6, logp(x|y)=-72.08, time=2.86
# Iter 7, logp(x|y)=-71.90, time=2.87
# Iter 8, logp(x|y)=-71.83, time=2.88
# Iter 9, logp(x|y)=-71.86, time=2.83
# Iter 10, logp(x|y)=-71.73, time=2.83
# test data approx Bayes classifier acc=87.05, bound=-71.19, time=1.72, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-71.66, time=2.92
# Iter 2, logp(x|y)=-71.61, time=2.84
# Iter 3, logp(x|y)=-71.64, time=2.84
# Iter 4, logp(x|y)=-71.49, time=2.84
# Iter 5, logp(x|y)=-71.44, time=2.89
# Iter 6, logp(x|y)=-71.37, time=2.90
# Iter 7, logp(x|y)=-71.44, time=2.85
# Iter 8, logp(x|y)=-71.35, time=2.86
# Iter 9, logp(x|y)=-71.31, time=2.86
# Iter 10, logp(x|y)=-71.16, time=2.91
# test data approx Bayes classifier acc=88.05, bound=-70.74, time=1.73, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-71.12, time=2.86
# Iter 2, logp(x|y)=-70.99, time=2.86
# Iter 3, logp(x|y)=-70.97, time=2.93
# Iter 4, logp(x|y)=-70.95, time=2.90
# Iter 5, logp(x|y)=-70.84, time=2.88
# Iter 6, logp(x|y)=-70.79, time=2.88
# Iter 7, logp(x|y)=-70.77, time=2.90
# Iter 8, logp(x|y)=-70.66, time=2.93
# Iter 9, logp(x|y)=-70.61, time=2.88
# Iter 10, logp(x|y)=-70.63, time=2.88
# test data approx Bayes classifier acc=86.10, bound=-70.47, time=1.74, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-70.56, time=2.96
# Iter 2, logp(x|y)=-70.37, time=2.88
# Iter 3, logp(x|y)=-70.34, time=2.88
# Iter 4, logp(x|y)=-70.28, time=2.87
# Iter 5, logp(x|y)=-70.24, time=2.95
# Iter 6, logp(x|y)=-70.18, time=2.88
# Iter 7, logp(x|y)=-70.05, time=2.86
# Iter 8, logp(x|y)=-70.08, time=2.85
# Iter 9, logp(x|y)=-70.08, time=2.89
# Iter 10, logp(x|y)=-69.98, time=2.89
# test data approx Bayes classifier acc=87.65, bound=-69.71, time=1.73, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-69.87, time=2.87
# Iter 2, logp(x|y)=-69.91, time=2.86
# Iter 3, logp(x|y)=-69.81, time=2.93
# Iter 4, logp(x|y)=-69.74, time=2.86
# Iter 5, logp(x|y)=-69.79, time=2.85
# Iter 6, logp(x|y)=-69.63, time=2.85
# Iter 7, logp(x|y)=-69.63, time=2.91
# Iter 8, logp(x|y)=-69.60, time=2.88
# Iter 9, logp(x|y)=-69.63, time=2.84
# Iter 10, logp(x|y)=-69.42, time=2.85
# test data approx Bayes classifier acc=86.80, bound=-69.34, time=1.72, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-69.41, time=3.06
# Iter 2, logp(x|y)=-69.39, time=2.87
# Iter 3, logp(x|y)=-69.32, time=2.86
# Iter 4, logp(x|y)=-69.28, time=2.87
# Iter 5, logp(x|y)=-69.16, time=3.00
# Iter 6, logp(x|y)=-69.18, time=2.86
# Iter 7, logp(x|y)=-69.13, time=2.87
# Iter 8, logp(x|y)=-69.12, time=2.87
# Iter 9, logp(x|y)=-69.13, time=2.92
# Iter 10, logp(x|y)=-69.07, time=2.87
# test data approx Bayes classifier acc=88.20, bound=-69.01, time=1.72, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-69.01, time=2.86
# Iter 2, logp(x|y)=-68.98, time=2.88
# Iter 3, logp(x|y)=-68.84, time=2.95
# Iter 4, logp(x|y)=-68.85, time=2.87
# Iter 5, logp(x|y)=-68.77, time=2.87
# Iter 6, logp(x|y)=-68.73, time=2.86
# Iter 7, logp(x|y)=-68.69, time=2.94
# Iter 8, logp(x|y)=-68.61, time=2.85
# Iter 9, logp(x|y)=-68.71, time=2.86
# Iter 10, logp(x|y)=-68.56, time=2.87
# test data approx Bayes classifier acc=87.10, bound=-68.88, time=1.73, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-68.59, time=2.94
# Iter 2, logp(x|y)=-68.45, time=2.88
# Iter 3, logp(x|y)=-68.50, time=2.88
# Iter 4, logp(x|y)=-68.48, time=2.88
# Iter 5, logp(x|y)=-68.38, time=2.97
# Iter 6, logp(x|y)=-68.36, time=2.89
# Iter 7, logp(x|y)=-68.29, time=2.88
# Iter 8, logp(x|y)=-68.33, time=2.87
# Iter 9, logp(x|y)=-68.28, time=2.97
# Iter 10, logp(x|y)=-68.28, time=2.86
# test data approx Bayes classifier acc=87.45, bound=-68.72, time=1.74, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-68.17, time=2.88
# Iter 2, logp(x|y)=-68.13, time=2.89
# Iter 3, logp(x|y)=-68.13, time=2.93
# Iter 4, logp(x|y)=-68.12, time=2.87
# Iter 5, logp(x|y)=-68.06, time=2.88
# Iter 6, logp(x|y)=-68.10, time=2.88
# Iter 7, logp(x|y)=-68.02, time=2.96
# Iter 8, logp(x|y)=-67.96, time=2.85
# Iter 9, logp(x|y)=-67.93, time=2.90
# Iter 10, logp(x|y)=-67.88, time=2.89
# test data approx Bayes classifier acc=88.95, bound=-68.38, time=1.75, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-67.91, time=2.91
# Iter 2, logp(x|y)=-67.78, time=2.87
# Iter 3, logp(x|y)=-67.93, time=2.93
# Iter 4, logp(x|y)=-67.75, time=2.90
# Iter 5, logp(x|y)=-67.77, time=2.92
# Iter 6, logp(x|y)=-67.72, time=2.87
# Iter 7, logp(x|y)=-67.69, time=2.86
# Iter 8, logp(x|y)=-67.69, time=2.88
# Iter 9, logp(x|y)=-67.73, time=3.01
# Iter 10, logp(x|y)=-67.57, time=2.86
# test data approx Bayes classifier acc=87.75, bound=-68.14, time=1.73, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-67.55, time=2.86
# Iter 2, logp(x|y)=-67.55, time=2.90
# Iter 3, logp(x|y)=-67.56, time=2.87
# Iter 4, logp(x|y)=-67.47, time=2.87
# Iter 5, logp(x|y)=-67.46, time=2.87
# Iter 6, logp(x|y)=-67.40, time=2.89
# Iter 7, logp(x|y)=-67.36, time=2.89
# Iter 8, logp(x|y)=-67.36, time=2.86
# Iter 9, logp(x|y)=-67.41, time=2.85
# Iter 10, logp(x|y)=-67.28, time=2.88
# test data approx Bayes classifier acc=87.75, bound=-68.22, time=1.76, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-67.27, time=2.85
# Iter 2, logp(x|y)=-67.35, time=2.86
# Iter 3, logp(x|y)=-67.22, time=2.87
# Iter 4, logp(x|y)=-67.23, time=2.91
# Iter 5, logp(x|y)=-67.18, time=2.88
# Iter 6, logp(x|y)=-67.13, time=2.85
# Iter 7, logp(x|y)=-67.15, time=2.85
# Iter 8, logp(x|y)=-67.12, time=2.87
# Iter 9, logp(x|y)=-67.08, time=2.91
# Iter 10, logp(x|y)=-67.04, time=2.86
# test data approx Bayes classifier acc=89.20, bound=-67.92, time=1.72, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-67.02, time=2.86
# Iter 2, logp(x|y)=-67.02, time=2.95
# Iter 3, logp(x|y)=-66.94, time=2.86
# Iter 4, logp(x|y)=-66.99, time=2.85
# Iter 5, logp(x|y)=-66.92, time=2.86
# Iter 6, logp(x|y)=-66.82, time=2.92
# Iter 7, logp(x|y)=-66.88, time=2.88
# Iter 8, logp(x|y)=-66.84, time=2.86
# Iter 9, logp(x|y)=-66.84, time=2.85
# Iter 10, logp(x|y)=-66.82, time=2.89
# test data approx Bayes classifier acc=88.35, bound=-67.79, time=1.75, beta=1.00
# parameters saved at save/plane_frog_conv_vae_F_128/checkpoint_0.pkl

# %% [markdown]
# Train the GBZ model

# %%
# !python vae_cifar_binary.py B
# Out:
# 2025-12-10 11:48:58.564044: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765367338.584392   37081 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765367338.590307   37081 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765367338.607154   37081 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765367338.607182   37081 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765367338.607186   37081 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765367338.607192   37081 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# decoder shared Conv Net of size [(4, 4, 256), (8, 8, 128), (16, 16, 64), (32, 32, 3)]
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# encoder shared Conv net  network architecture: [(16, 16, 64), (8, 8, 128), (4, 4, 256)] [1000]
# I0000 00:00:1765367346.518638   37081 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11780 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# create path save/plane_frog_conv_vae_B_128/
# training from scratch
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/tf_should_use.py:288: initialize_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.variables_initializer` instead.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765367346.546563   37081 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# training for 10 epochs with lr=0.00005, beta=1.00
# I0000 00:00:1765367347.588929   37136 cuda_dnn.cc:529] Loaded cuDNN version 91002
# Iter 1, logp(x|y)=-192.52, time=4.17
# Iter 2, logp(x|y)=-167.62, time=2.61
# Iter 3, logp(x|y)=-132.34, time=2.62
# Iter 4, logp(x|y)=-117.76, time=2.69
# Iter 5, logp(x|y)=-113.26, time=2.67
# Iter 6, logp(x|y)=-109.33, time=2.64
# Iter 7, logp(x|y)=-107.89, time=2.65
# Iter 8, logp(x|y)=-106.03, time=2.65
# Iter 9, logp(x|y)=-103.14, time=2.72
# Iter 10, logp(x|y)=-99.50, time=2.65
# test data approx Bayes classifier acc=80.15, bound=-97.35, time=3.69, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-96.90, time=2.66
# Iter 2, logp(x|y)=-94.92, time=2.73
# Iter 3, logp(x|y)=-93.36, time=2.67
# Iter 4, logp(x|y)=-92.25, time=2.66
# Iter 5, logp(x|y)=-90.87, time=2.67
# Iter 6, logp(x|y)=-87.37, time=2.69
# Iter 7, logp(x|y)=-85.09, time=2.73
# Iter 8, logp(x|y)=-84.01, time=2.68
# Iter 9, logp(x|y)=-82.95, time=2.68
# Iter 10, logp(x|y)=-82.36, time=2.69
# test data approx Bayes classifier acc=84.90, bound=-81.47, time=1.61, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-81.72, time=2.76
# Iter 2, logp(x|y)=-80.97, time=2.69
# Iter 3, logp(x|y)=-80.36, time=2.70
# Iter 4, logp(x|y)=-79.68, time=2.70
# Iter 5, logp(x|y)=-79.36, time=2.78
# Iter 6, logp(x|y)=-79.19, time=2.70
# Iter 7, logp(x|y)=-78.80, time=2.70
# Iter 8, logp(x|y)=-78.46, time=2.70
# Iter 9, logp(x|y)=-78.15, time=2.74
# Iter 10, logp(x|y)=-78.00, time=2.75
# test data approx Bayes classifier acc=84.60, bound=-77.60, time=1.62, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-77.84, time=2.72
# Iter 2, logp(x|y)=-77.69, time=2.71
# Iter 3, logp(x|y)=-77.61, time=2.75
# Iter 4, logp(x|y)=-77.36, time=2.76
# Iter 5, logp(x|y)=-77.05, time=2.72
# Iter 6, logp(x|y)=-76.88, time=2.72
# Iter 7, logp(x|y)=-76.82, time=2.72
# Iter 8, logp(x|y)=-76.58, time=2.83
# Iter 9, logp(x|y)=-76.37, time=2.75
# Iter 10, logp(x|y)=-76.21, time=2.75
# test data approx Bayes classifier acc=86.25, bound=-75.31, time=1.67, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-75.94, time=2.80
# Iter 2, logp(x|y)=-75.76, time=2.86
# Iter 3, logp(x|y)=-75.67, time=2.79
# Iter 4, logp(x|y)=-75.50, time=2.79
# Iter 5, logp(x|y)=-75.40, time=2.80
# Iter 6, logp(x|y)=-75.28, time=2.87
# Iter 7, logp(x|y)=-75.21, time=2.82
# Iter 8, logp(x|y)=-75.08, time=2.81
# Iter 9, logp(x|y)=-74.91, time=2.81
# Iter 10, logp(x|y)=-74.89, time=2.85
# test data approx Bayes classifier acc=87.25, bound=-74.46, time=1.71, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-74.79, time=2.80
# Iter 2, logp(x|y)=-74.73, time=2.81
# Iter 3, logp(x|y)=-74.60, time=2.79
# Iter 4, logp(x|y)=-74.59, time=2.84
# Iter 5, logp(x|y)=-74.56, time=2.79
# Iter 6, logp(x|y)=-74.30, time=2.79
# Iter 7, logp(x|y)=-74.19, time=2.78
# Iter 8, logp(x|y)=-74.15, time=2.80
# Iter 9, logp(x|y)=-74.12, time=2.81
# Iter 10, logp(x|y)=-73.94, time=2.76
# test data approx Bayes classifier acc=87.75, bound=-73.60, time=1.67, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-73.80, time=2.77
# Iter 2, logp(x|y)=-73.76, time=2.81
# Iter 3, logp(x|y)=-73.56, time=2.78
# Iter 4, logp(x|y)=-73.35, time=2.76
# Iter 5, logp(x|y)=-73.31, time=2.76
# Iter 6, logp(x|y)=-73.12, time=2.77
# Iter 7, logp(x|y)=-73.05, time=2.82
# Iter 8, logp(x|y)=-72.99, time=2.76
# Iter 9, logp(x|y)=-72.82, time=2.77
# Iter 10, logp(x|y)=-72.67, time=2.77
# test data approx Bayes classifier acc=88.20, bound=-72.34, time=1.69, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-72.61, time=2.83
# Iter 2, logp(x|y)=-72.53, time=2.79
# Iter 3, logp(x|y)=-72.52, time=2.77
# Iter 4, logp(x|y)=-72.42, time=2.79
# Iter 5, logp(x|y)=-72.29, time=2.85
# Iter 6, logp(x|y)=-72.30, time=2.79
# Iter 7, logp(x|y)=-72.19, time=2.79
# Iter 8, logp(x|y)=-72.12, time=2.80
# Iter 9, logp(x|y)=-72.18, time=2.88
# Iter 10, logp(x|y)=-72.01, time=2.81
# test data approx Bayes classifier acc=89.50, bound=-71.73, time=1.69, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-71.99, time=2.80
# Iter 2, logp(x|y)=-71.92, time=2.79
# Iter 3, logp(x|y)=-71.87, time=2.88
# Iter 4, logp(x|y)=-71.81, time=2.80
# Iter 5, logp(x|y)=-71.82, time=2.79
# Iter 6, logp(x|y)=-71.67, time=2.79
# Iter 7, logp(x|y)=-71.65, time=2.84
# Iter 8, logp(x|y)=-71.65, time=2.81
# Iter 9, logp(x|y)=-71.57, time=2.79
# Iter 10, logp(x|y)=-71.49, time=2.78
# test data approx Bayes classifier acc=89.65, bound=-71.36, time=1.68, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-71.45, time=2.85
# Iter 2, logp(x|y)=-71.38, time=2.79
# Iter 3, logp(x|y)=-71.44, time=2.79
# Iter 4, logp(x|y)=-71.35, time=2.77
# Iter 5, logp(x|y)=-71.27, time=2.81
# Iter 6, logp(x|y)=-71.25, time=2.80
# Iter 7, logp(x|y)=-71.17, time=2.77
# Iter 8, logp(x|y)=-71.24, time=2.77
# Iter 9, logp(x|y)=-71.10, time=2.78
# Iter 10, logp(x|y)=-71.05, time=2.82
# test data approx Bayes classifier acc=89.35, bound=-71.04, time=1.66, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-71.01, time=2.76
# Iter 2, logp(x|y)=-71.03, time=2.76
# Iter 3, logp(x|y)=-70.94, time=2.80
# Iter 4, logp(x|y)=-70.82, time=2.82
# Iter 5, logp(x|y)=-70.80, time=2.77
# Iter 6, logp(x|y)=-70.81, time=2.77
# Iter 7, logp(x|y)=-70.76, time=2.77
# Iter 8, logp(x|y)=-70.69, time=2.84
# Iter 9, logp(x|y)=-70.61, time=2.77
# Iter 10, logp(x|y)=-70.55, time=2.78
# test data approx Bayes classifier acc=90.20, bound=-70.75, time=1.69, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-70.53, time=2.82
# Iter 2, logp(x|y)=-70.47, time=2.84
# Iter 3, logp(x|y)=-70.43, time=2.80
# Iter 4, logp(x|y)=-70.42, time=2.81
# Iter 5, logp(x|y)=-70.31, time=2.81
# Iter 6, logp(x|y)=-70.23, time=2.87
# Iter 7, logp(x|y)=-70.26, time=2.81
# Iter 8, logp(x|y)=-70.25, time=2.80
# Iter 9, logp(x|y)=-70.11, time=2.80
# Iter 10, logp(x|y)=-70.05, time=2.86
# test data approx Bayes classifier acc=90.35, bound=-70.39, time=1.70, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-70.09, time=2.80
# Iter 2, logp(x|y)=-70.01, time=2.80
# Iter 3, logp(x|y)=-69.96, time=2.80
# Iter 4, logp(x|y)=-69.88, time=2.86
# Iter 5, logp(x|y)=-69.89, time=2.78
# Iter 6, logp(x|y)=-69.81, time=2.78
# Iter 7, logp(x|y)=-69.88, time=2.78
# Iter 8, logp(x|y)=-69.71, time=2.81
# Iter 9, logp(x|y)=-69.69, time=2.80
# Iter 10, logp(x|y)=-69.74, time=2.77
# test data approx Bayes classifier acc=90.45, bound=-70.23, time=1.67, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-69.60, time=2.77
# Iter 2, logp(x|y)=-69.57, time=2.83
# Iter 3, logp(x|y)=-69.55, time=2.78
# Iter 4, logp(x|y)=-69.50, time=2.79
# Iter 5, logp(x|y)=-69.52, time=2.77
# Iter 6, logp(x|y)=-69.45, time=2.79
# Iter 7, logp(x|y)=-69.36, time=2.80
# Iter 8, logp(x|y)=-69.44, time=2.79
# Iter 9, logp(x|y)=-69.33, time=2.77
# Iter 10, logp(x|y)=-69.26, time=2.78
# test data approx Bayes classifier acc=90.55, bound=-70.10, time=1.69, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-69.27, time=2.80
# Iter 2, logp(x|y)=-69.21, time=2.77
# Iter 3, logp(x|y)=-69.17, time=2.76
# Iter 4, logp(x|y)=-69.17, time=2.78
# Iter 5, logp(x|y)=-69.11, time=2.83
# Iter 6, logp(x|y)=-69.09, time=2.77
# Iter 7, logp(x|y)=-69.02, time=2.77
# Iter 8, logp(x|y)=-69.05, time=2.78
# Iter 9, logp(x|y)=-68.96, time=2.84
# Iter 10, logp(x|y)=-68.92, time=2.79
# test data approx Bayes classifier acc=90.20, bound=-69.89, time=1.69, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-68.92, time=2.80
# Iter 2, logp(x|y)=-68.93, time=2.80
# Iter 3, logp(x|y)=-68.84, time=2.86
# Iter 4, logp(x|y)=-68.81, time=2.81
# Iter 5, logp(x|y)=-68.75, time=2.81
# Iter 6, logp(x|y)=-68.69, time=2.82
# Iter 7, logp(x|y)=-68.70, time=2.84
# Iter 8, logp(x|y)=-68.63, time=2.82
# Iter 9, logp(x|y)=-68.59, time=2.79
# Iter 10, logp(x|y)=-68.59, time=2.79
# test data approx Bayes classifier acc=91.35, bound=-69.85, time=1.69, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-68.46, time=2.85
# Iter 2, logp(x|y)=-68.54, time=2.78
# Iter 3, logp(x|y)=-68.50, time=2.78
# Iter 4, logp(x|y)=-68.37, time=2.78
# Iter 5, logp(x|y)=-68.40, time=2.81
# Iter 6, logp(x|y)=-68.41, time=2.83
# Iter 7, logp(x|y)=-68.30, time=2.78
# Iter 8, logp(x|y)=-68.33, time=2.77
# Iter 9, logp(x|y)=-68.20, time=2.78
# Iter 10, logp(x|y)=-68.23, time=2.85
# test data approx Bayes classifier acc=91.30, bound=-69.52, time=1.67, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-68.14, time=2.77
# Iter 2, logp(x|y)=-68.15, time=2.77
# Iter 3, logp(x|y)=-68.13, time=2.79
# Iter 4, logp(x|y)=-68.04, time=2.84
# Iter 5, logp(x|y)=-67.98, time=2.77
# Iter 6, logp(x|y)=-68.02, time=2.77
# Iter 7, logp(x|y)=-67.98, time=2.77
# Iter 8, logp(x|y)=-67.94, time=2.85
# Iter 9, logp(x|y)=-67.90, time=2.78
# Iter 10, logp(x|y)=-67.89, time=2.77
# test data approx Bayes classifier acc=91.35, bound=-69.72, time=1.68, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-67.83, time=2.78
# Iter 2, logp(x|y)=-67.73, time=2.86
# Iter 3, logp(x|y)=-67.70, time=2.79
# Iter 4, logp(x|y)=-67.68, time=2.78
# Iter 5, logp(x|y)=-67.60, time=2.78
# Iter 6, logp(x|y)=-67.66, time=2.83
# Iter 7, logp(x|y)=-67.62, time=2.80
# Iter 8, logp(x|y)=-67.60, time=2.78
# Iter 9, logp(x|y)=-67.48, time=2.78
# Iter 10, logp(x|y)=-67.50, time=2.79
# test data approx Bayes classifier acc=91.25, bound=-69.76, time=1.70, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-67.44, time=2.78
# Iter 2, logp(x|y)=-67.37, time=2.78
# Iter 3, logp(x|y)=-67.41, time=2.78
# Iter 4, logp(x|y)=-67.30, time=2.81
# Iter 5, logp(x|y)=-67.30, time=2.82
# Iter 6, logp(x|y)=-67.22, time=2.77
# Iter 7, logp(x|y)=-67.21, time=2.91
# Iter 8, logp(x|y)=-67.14, time=2.84
# Iter 9, logp(x|y)=-67.17, time=2.86
# Iter 10, logp(x|y)=-67.11, time=2.77
# test data approx Bayes classifier acc=92.10, bound=-69.67, time=1.67, beta=1.00
# parameters saved at save/plane_frog_conv_vae_B_128/checkpoint_0.pkl

# %% [markdown]
# Train the DFZ model

# %%
# !python vae_cifar_binary.py C
# Out:
# 2025-12-10 09:40:14.563450: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765359614.584770    4511 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765359614.591420    4511 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765359614.606477    4511 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765359614.606505    4511 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765359614.606509    4511 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765359614.606514    4511 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-10 09:40:14.611237: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# generator shared Conv net  network architecture: [(16, 16, 64), (8, 8, 128), (4, 4, 256)] [1000]
# decoder shared Conv Net of size [(4, 4, 256), (8, 8, 128), (16, 16, 64), (32, 32, 3)]
# encoder shared Conv net  network architecture: [(16, 16, 64), (8, 8, 128), (4, 4, 256)] [1000]
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/dispatch.py:1260: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# I0000 00:00:1765359623.077229    4511 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# create path save/plane_frog_conv_vae_C_128/
# training from scratch
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/tf_should_use.py:288: initialize_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.variables_initializer` instead.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765359623.101890    4511 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# training for 10 epochs with lr=0.00005, beta=1.00
# I0000 00:00:1765359624.193247    4566 cuda_dnn.cc:529] Loaded cuDNN version 91002
# Iter 1, logp(x|y)=-192.71, time=5.33
# Iter 2, logp(x|y)=-170.96, time=4.10
# Iter 3, logp(x|y)=-141.66, time=4.05
# Iter 4, logp(x|y)=-119.27, time=4.10
# Iter 5, logp(x|y)=-112.73, time=4.20
# Iter 6, logp(x|y)=-109.26, time=4.18
# Iter 7, logp(x|y)=-107.68, time=4.21
# Iter 8, logp(x|y)=-106.15, time=4.26
# Iter 9, logp(x|y)=-104.78, time=4.23
# Iter 10, logp(x|y)=-102.99, time=4.20
# test data approx Bayes classifier acc=91.10, bound=-100.61, time=5.71, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-100.59, time=4.16
# Iter 2, logp(x|y)=-98.33, time=4.20
# Iter 3, logp(x|y)=-96.07, time=4.17
# Iter 4, logp(x|y)=-94.54, time=4.16
# Iter 5, logp(x|y)=-93.89, time=4.17
# Iter 6, logp(x|y)=-93.19, time=4.16
# Iter 7, logp(x|y)=-92.61, time=4.13
# Iter 8, logp(x|y)=-92.00, time=4.14
# Iter 9, logp(x|y)=-91.11, time=4.36
# Iter 10, logp(x|y)=-90.06, time=4.35
# test data approx Bayes classifier acc=95.15, bound=-89.29, time=2.51, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-89.08, time=4.17
# Iter 2, logp(x|y)=-87.93, time=4.58
# Iter 3, logp(x|y)=-85.88, time=4.18
# Iter 4, logp(x|y)=-83.64, time=4.22
# Iter 5, logp(x|y)=-82.51, time=4.16
# Iter 6, logp(x|y)=-81.71, time=4.27
# Iter 7, logp(x|y)=-81.31, time=4.20
# Iter 8, logp(x|y)=-80.78, time=4.16
# Iter 9, logp(x|y)=-80.24, time=4.27
# Iter 10, logp(x|y)=-79.86, time=4.22
# test data approx Bayes classifier acc=95.95, bound=-79.40, time=2.53, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-79.57, time=4.20
# Iter 2, logp(x|y)=-79.14, time=4.19
# Iter 3, logp(x|y)=-78.80, time=4.16
# Iter 4, logp(x|y)=-78.69, time=4.20
# Iter 5, logp(x|y)=-78.44, time=4.17
# Iter 6, logp(x|y)=-78.29, time=4.14
# Iter 7, logp(x|y)=-78.02, time=4.25
# Iter 8, logp(x|y)=-77.82, time=4.15
# Iter 9, logp(x|y)=-77.48, time=4.14
# Iter 10, logp(x|y)=-77.32, time=4.18
# test data approx Bayes classifier acc=95.70, bound=-76.77, time=2.51, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-77.10, time=4.14
# Iter 2, logp(x|y)=-76.86, time=4.16
# Iter 3, logp(x|y)=-76.44, time=4.18
# Iter 4, logp(x|y)=-76.22, time=4.12
# Iter 5, logp(x|y)=-76.18, time=4.17
# Iter 6, logp(x|y)=-75.73, time=4.22
# Iter 7, logp(x|y)=-75.55, time=4.14
# Iter 8, logp(x|y)=-75.30, time=4.20
# Iter 9, logp(x|y)=-75.10, time=4.15
# Iter 10, logp(x|y)=-74.84, time=4.12
# test data approx Bayes classifier acc=96.15, bound=-74.42, time=2.54, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-74.63, time=4.20
# Iter 2, logp(x|y)=-74.48, time=4.14
# Iter 3, logp(x|y)=-74.29, time=4.17
# Iter 4, logp(x|y)=-74.05, time=4.33
# Iter 5, logp(x|y)=-73.98, time=4.31
# Iter 6, logp(x|y)=-73.85, time=4.38
# Iter 7, logp(x|y)=-73.79, time=4.36
# Iter 8, logp(x|y)=-73.56, time=4.29
# Iter 9, logp(x|y)=-73.39, time=4.23
# Iter 10, logp(x|y)=-73.38, time=4.15
# test data approx Bayes classifier acc=95.85, bound=-73.05, time=2.52, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-73.18, time=4.21
# Iter 2, logp(x|y)=-73.21, time=4.15
# Iter 3, logp(x|y)=-72.96, time=4.15
# Iter 4, logp(x|y)=-72.88, time=4.21
# Iter 5, logp(x|y)=-72.74, time=4.20
# Iter 6, logp(x|y)=-72.75, time=4.13
# Iter 7, logp(x|y)=-72.66, time=4.26
# Iter 8, logp(x|y)=-72.63, time=4.27
# Iter 9, logp(x|y)=-72.39, time=4.16
# Iter 10, logp(x|y)=-72.38, time=4.21
# test data approx Bayes classifier acc=95.90, bound=-72.19, time=2.52, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-72.26, time=4.13
# Iter 2, logp(x|y)=-72.23, time=4.20
# Iter 3, logp(x|y)=-72.21, time=4.17
# Iter 4, logp(x|y)=-72.07, time=4.23
# Iter 5, logp(x|y)=-72.00, time=4.26
# Iter 6, logp(x|y)=-71.84, time=4.16
# Iter 7, logp(x|y)=-71.69, time=4.15
# Iter 8, logp(x|y)=-71.77, time=4.23
# Iter 9, logp(x|y)=-71.56, time=4.17
# Iter 10, logp(x|y)=-71.56, time=4.14
# test data approx Bayes classifier acc=95.85, bound=-71.48, time=2.54, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-71.46, time=4.17
# Iter 2, logp(x|y)=-71.24, time=4.15
# Iter 3, logp(x|y)=-71.38, time=4.18
# Iter 4, logp(x|y)=-71.22, time=4.14
# Iter 5, logp(x|y)=-71.07, time=4.13
# Iter 6, logp(x|y)=-70.94, time=4.19
# Iter 7, logp(x|y)=-70.88, time=4.13
# Iter 8, logp(x|y)=-70.84, time=4.16
# Iter 9, logp(x|y)=-70.82, time=4.21
# Iter 10, logp(x|y)=-70.70, time=4.14
# test data approx Bayes classifier acc=95.75, bound=-70.65, time=2.52, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-70.60, time=4.22
# Iter 2, logp(x|y)=-70.47, time=4.45
# Iter 3, logp(x|y)=-70.45, time=4.17
# Iter 4, logp(x|y)=-70.41, time=4.22
# Iter 5, logp(x|y)=-70.34, time=4.14
# Iter 6, logp(x|y)=-70.19, time=4.14
# Iter 7, logp(x|y)=-70.27, time=4.20
# Iter 8, logp(x|y)=-70.17, time=4.16
# Iter 9, logp(x|y)=-70.16, time=4.15
# Iter 10, logp(x|y)=-70.07, time=4.22
# test data approx Bayes classifier acc=95.90, bound=-70.75, time=2.52, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-70.03, time=4.17
# Iter 2, logp(x|y)=-69.95, time=4.23
# Iter 3, logp(x|y)=-69.87, time=4.15
# Iter 4, logp(x|y)=-69.90, time=4.14
# Iter 5, logp(x|y)=-69.81, time=4.29
# Iter 6, logp(x|y)=-69.83, time=4.16
# Iter 7, logp(x|y)=-69.72, time=4.12
# Iter 8, logp(x|y)=-69.74, time=4.18
# Iter 9, logp(x|y)=-69.64, time=4.15
# Iter 10, logp(x|y)=-69.66, time=4.14
# test data approx Bayes classifier acc=95.70, bound=-69.84, time=2.54, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-69.57, time=4.17
# Iter 2, logp(x|y)=-69.51, time=4.14
# Iter 3, logp(x|y)=-69.52, time=4.17
# Iter 4, logp(x|y)=-69.47, time=4.12
# Iter 5, logp(x|y)=-69.45, time=4.16
# Iter 6, logp(x|y)=-69.36, time=4.24
# Iter 7, logp(x|y)=-69.31, time=4.17
# Iter 8, logp(x|y)=-69.39, time=4.13
# Iter 9, logp(x|y)=-69.30, time=4.21
# Iter 10, logp(x|y)=-69.17, time=4.15
# test data approx Bayes classifier acc=95.70, bound=-69.80, time=2.52, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-69.18, time=4.22
# Iter 2, logp(x|y)=-69.20, time=4.16
# Iter 3, logp(x|y)=-69.07, time=4.13
# Iter 4, logp(x|y)=-69.11, time=4.21
# Iter 5, logp(x|y)=-69.02, time=4.13
# Iter 6, logp(x|y)=-69.00, time=4.14
# Iter 7, logp(x|y)=-68.97, time=4.19
# Iter 8, logp(x|y)=-68.97, time=4.13
# Iter 9, logp(x|y)=-68.95, time=4.13
# Iter 10, logp(x|y)=-68.94, time=4.18
# test data approx Bayes classifier acc=95.75, bound=-69.62, time=2.53, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-68.86, time=4.15
# Iter 2, logp(x|y)=-68.87, time=4.19
# Iter 3, logp(x|y)=-68.79, time=4.14
# Iter 4, logp(x|y)=-68.72, time=4.13
# Iter 5, logp(x|y)=-68.76, time=4.21
# Iter 6, logp(x|y)=-68.77, time=4.14
# Iter 7, logp(x|y)=-68.63, time=4.13
# Iter 8, logp(x|y)=-68.67, time=4.21
# Iter 9, logp(x|y)=-68.60, time=4.13
# Iter 10, logp(x|y)=-68.60, time=4.25
# test data approx Bayes classifier acc=95.85, bound=-69.38, time=2.80, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-68.54, time=4.21
# Iter 2, logp(x|y)=-68.54, time=4.17
# Iter 3, logp(x|y)=-68.50, time=4.21
# Iter 4, logp(x|y)=-68.56, time=4.15
# Iter 5, logp(x|y)=-68.42, time=4.12
# Iter 6, logp(x|y)=-68.42, time=4.17
# Iter 7, logp(x|y)=-68.41, time=4.13
# Iter 8, logp(x|y)=-68.36, time=4.16
# Iter 9, logp(x|y)=-68.34, time=4.20
# Iter 10, logp(x|y)=-68.29, time=4.13
# test data approx Bayes classifier acc=96.00, bound=-68.91, time=2.56, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-68.20, time=4.18
# Iter 2, logp(x|y)=-68.22, time=4.13
# Iter 3, logp(x|y)=-68.22, time=4.14
# Iter 4, logp(x|y)=-68.18, time=4.21
# Iter 5, logp(x|y)=-68.11, time=4.16
# Iter 6, logp(x|y)=-68.19, time=4.30
# Iter 7, logp(x|y)=-68.12, time=4.21
# Iter 8, logp(x|y)=-68.13, time=4.15
# Iter 9, logp(x|y)=-68.10, time=4.15
# Iter 10, logp(x|y)=-67.99, time=4.18
# test data approx Bayes classifier acc=96.00, bound=-68.90, time=2.51, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-67.94, time=4.14
# Iter 2, logp(x|y)=-68.07, time=4.18
# Iter 3, logp(x|y)=-67.95, time=4.15
# Iter 4, logp(x|y)=-67.85, time=4.14
# Iter 5, logp(x|y)=-67.89, time=4.21
# Iter 6, logp(x|y)=-67.89, time=4.16
# Iter 7, logp(x|y)=-67.81, time=4.16
# Iter 8, logp(x|y)=-67.82, time=4.19
# Iter 9, logp(x|y)=-67.76, time=4.28
# Iter 10, logp(x|y)=-67.80, time=4.26
# test data approx Bayes classifier acc=95.90, bound=-68.96, time=2.54, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-67.72, time=4.17
# Iter 2, logp(x|y)=-67.69, time=4.39
# Iter 3, logp(x|y)=-67.69, time=4.20
# Iter 4, logp(x|y)=-67.68, time=4.13
# Iter 5, logp(x|y)=-67.65, time=4.22
# Iter 6, logp(x|y)=-67.65, time=4.20
# Iter 7, logp(x|y)=-67.60, time=4.15
# Iter 8, logp(x|y)=-67.52, time=4.34
# Iter 9, logp(x|y)=-67.50, time=4.22
# Iter 10, logp(x|y)=-67.47, time=4.12
# test data approx Bayes classifier acc=95.95, bound=-68.65, time=2.51, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-67.54, time=4.19
# Iter 2, logp(x|y)=-67.45, time=4.12
# Iter 3, logp(x|y)=-67.42, time=4.14
# Iter 4, logp(x|y)=-67.35, time=4.21
# Iter 5, logp(x|y)=-67.39, time=4.13
# Iter 6, logp(x|y)=-67.40, time=4.13
# Iter 7, logp(x|y)=-67.33, time=4.22
# Iter 8, logp(x|y)=-67.30, time=4.15
# Iter 9, logp(x|y)=-67.25, time=4.14
# Iter 10, logp(x|y)=-67.24, time=4.20
# test data approx Bayes classifier acc=96.10, bound=-68.88, time=2.51, beta=1.00
# training for 10 epochs with lr=0.00005, beta=1.00
# Iter 1, logp(x|y)=-67.20, time=4.14
# Iter 2, logp(x|y)=-67.26, time=4.19
# Iter 3, logp(x|y)=-67.11, time=4.15
# Iter 4, logp(x|y)=-67.12, time=4.12
# Iter 5, logp(x|y)=-67.10, time=4.19
# Iter 6, logp(x|y)=-67.06, time=4.11
# Iter 7, logp(x|y)=-67.07, time=4.20
# Iter 8, logp(x|y)=-67.05, time=4.15
# Iter 9, logp(x|y)=-67.05, time=4.10
# Iter 10, logp(x|y)=-66.96, time=4.13
# test data approx Bayes classifier acc=95.80, bound=-68.39, time=2.53, beta=1.00
# parameters saved at save/plane_frog_conv_vae_C_128/checkpoint_0.pkl

# %% [markdown]
# **In distribution data vizualisation**

# %%
# Classes CIFAR-10
CIFAR10_CLASSES = {
    0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer',
    5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck'
}

print("Classes CIFAR-10 disponibles:")
for k, v in CIFAR10_CLASSES.items():
    print(f"  {k}: {v}")
# Out:
# Classes CIFAR-10 disponibles:
#   0: airplane
#   1: automobile
#   2: bird
#   3: cat
#   4: deer
#   5: dog
#   6: frog
#   7: horse
#   8: ship
#   9: truck

# %%
# Classes ID (In-Distribution)
ID_CLASSES = [0, 6]  # airplane, frog
print(f"Classes ID: {[CIFAR10_CLASSES[c] for c in ID_CLASSES]}")
# Out:
# Classes ID: ['airplane', 'frog']

# %%
cd /content/my_deepBayes/
# Out:
# /content/my_deepBayes

# %%
# Load ID dta
data_path = 'cifar_data/'
from utils.import_data_cifar10 import load_data_cifar10
import matplotlib.pyplot as plt
import numpy as np
X_train, X_test, Y_train, Y_test = load_data_cifar10(
    data_path, labels=ID_CLASSES, conv=True
)
dimY = Y_train.shape[1]

print(f"\Loaded data:")
print(f"  Train: {X_train.shape}, Test: {X_test.shape}")
print(f"  Classes: {dimY}")
# Out:
# Données chargées:
#   Train: (10000, 32, 32, 3), Test: (2000, 32, 32, 3)
#   Classes: 2

# %%
n_images = 10
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.flatten()

for i in range(n_images):
    axes[i].imshow(X_train[i])
    class_idx = ID_CLASSES[np.argmax(Y_train[i])]
    axes[i].set_title(f'{CIFAR10_CLASSES[class_idx]}')
    axes[i].axis('off')

plt.suptitle('Samples ID (Plane/Frog)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# **OOD detection using typicality**

# %%
cd /content/my_deepBayes/
# Out:
# /content/my_deepBayes

# %%
# Cell 1: Imports & Setup
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
from six.moves import xrange
import os, sys, pickle
import matplotlib.pyplot as plt
import tensorflow.compat.v1 as tf

# Configure TF for legacy v1 behavior
tf.disable_v2_behavior()


try:
    from utils.import_data_cifar10 import load_data_cifar10
except ImportError:
    print("Warning: Custom modules 'load_classifier' or 'import_data_cifar10' not found.")
    print("Please ensure you are in the correct directory or have uploaded the 'load' and 'utils' folders.")

# %%
cd /content/my_deepBayes/test_attacks/
# Out:
# /content/my_deepBayes/test_attacks

# %%
try:
    from load.load_classifier import load_classifier
except ImportError:
    print("Warning: Custom modules 'load_classifier' or 'import_data_cifar10' not found.")
    print("Please ensure you are in the correct directory or have uploaded the 'load' and 'utils' folders.")

# %%
# Cell 2: Helper Functions

def compute_empirical_entropy(logit):
    """
    Computes empirical entropy: H_hat = 1/N * sum(-log p(x))
    Returns negative log-likelihood scores.
    """
    neg_logpx = -logit
    return neg_logpx

def compute_test_statistic(neg_logpx_batch, resubstitution_entropy_hat):
    """
    Computes the typicality test statistic:
    | 1/M * sum(-log p(x)) - H_hat_RESUB | = epsilon_hat
    """
    sample_entropy_hat = np.mean(neg_logpx_batch)
    epsilon_hat = np.abs(sample_entropy_hat - resubstitution_entropy_hat)
    return epsilon_hat

def compute_all_epsilon_scores(sess, y_logit_op, x_placeholder, data_x, M, H_hat_RESUB):
    """Computes epsilon_hat scores for all full M-sized batches."""
    epsilon_scores = []
    n_samples = data_x.shape[0]
    n_batches = int(n_samples / M)

    for i in xrange(n_batches):
        X_batch = data_x[i*M:(i+1)*M]
        logit_batch = sess.run(y_logit_op, feed_dict={x_placeholder: X_batch})
        neg_logpx_batch = compute_empirical_entropy(logit_batch)
        epsilon_hat = compute_test_statistic(neg_logpx_batch, H_hat_RESUB)
        epsilon_scores.append(epsilon_hat)

    return epsilon_scores, n_batches

def detect_typicality_rate_from_scores(epsilon_scores, n_batches, epsilon_alpha_M, is_ood_set=False):
    """Calculates detection rates based on the threshold."""
    if n_batches == 0:
        detection_rate = 0.0
    else:
        batches_classified_ood = np.sum(np.array(epsilon_scores) > epsilon_alpha_M)
        detection_rate = (batches_classified_ood / n_batches) * 100

    if is_ood_set:
        print(f'OOD Detection Rate (TP Rate) on {n_batches} batches: {detection_rate:.4f} %')
    else:
        print(f'False Alarm Rate (FP Rate) on {n_batches} batches: {detection_rate:.4f} %')

    return detection_rate

# %%
cd /content/my_deepBayes/test_attacks/   #just to make sure
# Out:
# /content/my_deepBayes/test_attacks

# %%
# Cell 4: Main Execution

def run_typicality_test(config):
    tf.reset_default_graph()
    try:
      tf.keras.backend.clear_session()
    except:
      pass # In case Keras isn't loaded yet

    print("Graph and Keras Backend reset. Ready for clean run.")
    tf.set_random_seed(1234)
    np.random.seed(1234)

    # Session Config
    sess_config = tf.ConfigProto()
    sess_config.gpu_options.allow_growth = True
    sess = tf.Session(config=sess_config)
    print("Created TensorFlow session.")

    # --- 1. Load Data ---
    img_rows, img_cols, channels = 32, 32, 3
    datapath = '../cifar_data/'

    # Load Full Data
    try:
        x_train_full, X_all_test, y_train_full, Y_all_test = load_data_cifar10(datapath, labels=None)
        # Load ID Train Data (Plane/Frog)
        x_train, _, _, _ = load_data_cifar10(datapath, labels=[0, 6])
    except NameError:
        print("Error: Data loading functions not defined. Make sure Cell 1 imports succeeded.")
        return

    # Filter Test Data
    all_labels = np.argmax(Y_all_test, axis=1)

    # 1.1 ID Test Set (Plane/Frog)
    id_indices = np.where((all_labels == 0) | (all_labels == 6))[0]
    x_clean = X_all_test[id_indices]

    # 1.2 OOD Test Set (Single Class from config)
    ood_idx = config['ood_class_index']
    ood_indices = np.where(all_labels == ood_idx)[0]
    x_ood = X_all_test[ood_indices]

    cifar10_names = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
    ood_label = cifar10_names[ood_idx]

    print(f'Loaded ID Train: {x_train.shape[0]}, ID Test: {x_clean.shape[0]}')
    print(f'Loaded OOD Test (Class {ood_idx}: {ood_label}): {x_ood.shape[0]}')

    # 1.3 Validation Split
    x_val = x_clean[1000:]
    x_clean = x_clean[:1000]
    M = config['batch_size']

    # --- 2. Load Model ---
    x_placeholder = tf.placeholder(tf.float32, shape=(M, img_rows, img_cols, channels))

    # Load your classifier
    gen = load_classifier(sess, config['guard_name'], config['data_name'])
    y_logit_op = gen.predict(x_placeholder, softmax=False)

    # --- 3. Compute Entropy (Offline Step) ---
    def compute_logits_all(data_x):
        logits = []
        n_samples = data_x.shape[0]
        n_batch = int(n_samples / M)

        for i in xrange(n_batch):
            X_batch = data_x[i*M:(i+1)*M]
            logits.append(sess.run(y_logit_op, feed_dict={x_placeholder: X_batch}))

        return np.concatenate(logits, 0)

    print("\nComputing training logits...")
    y_logit_train = compute_logits_all(x_train)
    neg_logpx_train = compute_empirical_entropy(y_logit_train)
    H_hat_RESUB = np.mean(neg_logpx_train)
    print(f'Resubstitution Entropy Estimate (H_hat_RESUB): {H_hat_RESUB:.3f}')

    # --- 4. Bootstrap (Threshold Setting) ---
    print(f'Computing Bootstrap (K={config["K_bootstrap"]}, M={M})...')
    epsilon_hat_bootstrap = []
    n_val = x_val.shape[0]

    for k in xrange(config['K_bootstrap']):
        idx = np.random.choice(n_val, size=M, replace=True)
        X_k_prime = x_val[idx]
        logit_k = sess.run(y_logit_op, feed_dict={x_placeholder: X_k_prime})
        neg_logpx_k = compute_empirical_entropy(logit_k)
        epsilon_hat_k = compute_test_statistic(neg_logpx_k, H_hat_RESUB)
        epsilon_hat_bootstrap.append(epsilon_hat_k)

    epsilon_alpha_M = np.quantile(epsilon_hat_bootstrap, config['alpha'])
    print(f'Rejection Threshold: {epsilon_alpha_M:.3f}')

    # --- 5. Detection (Online Step) ---
    id_scores, n_id = compute_all_epsilon_scores(sess, y_logit_op, x_placeholder, x_clean, M, H_hat_RESUB)
    ood_scores, n_ood = compute_all_epsilon_scores(sess, y_logit_op, x_placeholder, x_ood, M, H_hat_RESUB)

    detect_typicality_rate_from_scores(id_scores, n_id, epsilon_alpha_M, False)
    detect_typicality_rate_from_scores(ood_scores, n_ood, epsilon_alpha_M, True)

    # --- 6. Visualization ---
    plt.figure(figsize=(10, 6))
    plt.hist(ood_scores, bins=50, density=True, alpha=0.6, label=f'OOD ({ood_label})', color='red')
    plt.hist(id_scores, bins=50, density=True, alpha=0.6, label='ID (Plane/Frog)', color='blue')
    plt.axvline(epsilon_alpha_M, color='k', linestyle='--', linewidth=2, label='Threshold')

    plt.xlabel('Typicality Score')
    plt.ylabel('Frequency')
    plt.title(f'Typicality Scores (M={M})')
    plt.legend()
    plt.grid(axis='y', alpha=0.5)
    plt.show()

    sess.close()

# %% [markdown]
# OOD detection for GFZ

# %%
# Configuration Parameters

CONFIG_F = {
    'batch_size': 10,       # M in the paper
    'data_name': 'plane_frog',
    'guard_name': 'bayes_K10_F', #for the GFZ model
    'save_results': False,
    'alpha': 0.95,           # Confidence level
    'K_bootstrap': 1000,     # Number of bootstrap samples
    'ood_class_index': 1,    # 1 = Car (See list below for others)
}

# CIFAR-10 Class Reference:
# 0: plane, 1: car, 2: bird, 3: cat, 4: deer,
# 5: dog, 6: frog, 7: horse, 8: ship, 9: truck
# Run the function with our config
run_typicality_test(CONFIG_F)

# %% [markdown]
# OOD detection for GBZ

# %%
# Configuration Parameters

CONFIG_B = {
    'batch_size': 10,       # M in the paper
    'data_name': 'plane_frog',
    'guard_name': 'bayes_K10_B', # for the GBZ model
    'save_results': False,
    'alpha': 0.95,           # Confidence level
    'K_bootstrap': 1000,     # Number of bootstrap samples
    'ood_class_index': 1,    # 1 = Car (See list below for others)
}

# CIFAR-10 Class Reference:
# 0: plane, 1: car, 2: bird, 3: cat, 4: deer,
# 5: dog, 6: frog, 7: horse, 8: ship, 9: truck
# Run the function with our config
run_typicality_test(CONFIG_B)

# %% [markdown]
# OOD detection for DFZ

# %%
# Configuration Parameters

CONFIG_C = {
    'batch_size': 10,       # M in the paper
    'data_name': 'plane_frog',
    'guard_name': 'bayes_K10_C', #for the DFZ model
    'save_results': False,
    'alpha': 0.95,           # Confidence level
    'K_bootstrap': 1000,     # Number of bootstrap samples
    'ood_class_index': 1,    # 1 = Car (See list below for others)
}

# CIFAR-10 Class Reference:
# 0: plane, 1: car, 2: bird, 3: cat, 4: deer,
# 5: dog, 6: frog, 7: horse, 8: ship, 9: truck

# Run the function with our config
run_typicality_test(CONFIG_C)

# %% [markdown]
# **OOD Detection via Log-Likelihood of Logits**

# %%
# Helper functions
def comp_logp(logit, y, text, comp_logit_dist=False):
    logpx = logsumexp(logit, axis=1)
    logpx_mean = np.mean(logpx)
    logpx_std = np.sqrt(np.var(logpx))

    logpxy = np.sum(y * logit, axis=1)
    logpxy_mean = []; logpxy_std = []

    for i in range(y.shape[1]):
        ind = np.where(y[:, i] == 1)[0]
        if len(ind) > 0:
            logpxy_mean.append(np.mean(logpxy[ind]))
            logpxy_std.append(np.sqrt(np.var(logpxy[ind])))

    print('%s: logp(x) = %.3f +- %.3f, logp(x|y) = %.3f +- %.3f' %
          (text, logpx_mean, logpx_std,
           np.mean(logpxy_mean) if logpxy_mean else 0,
           np.mean(logpxy_std) if logpxy_std else 0))

    return [logpx, logpx_mean, logpx_std, logpxy, logpxy_mean, logpxy_std]

def comp_detect(x, x_mean, x_std, alpha, plus):
    if plus:
        detect_rate = np.mean(x > x_mean + alpha * x_std)
    else:
        detect_rate = np.mean(x < x_mean - alpha * x_std)
    return detect_rate * 100

def search_alpha(x, x_mean, x_std, target_rate=5.0, plus=False):
    alpha_min, alpha_max, alpha_now = 0.0, 3.0, 1.5
    detect_rate = comp_detect(x, x_mean, x_std, alpha_now, plus)
    T = 0
    while np.abs(detect_rate - target_rate) > 0.01 and T < 20:
        if detect_rate > target_rate:
            alpha_min = alpha_now
        else:
            alpha_max = alpha_now
        alpha_now = 0.5 * (alpha_min + alpha_max)
        detect_rate = comp_detect(x, x_mean, x_std, alpha_now, plus)
        T += 1
    return alpha_now, detect_rate

# %%
def OOD_logit(batch_size=100, guard_name='bayes_K10', data_name='plane_frog', save=False):
    import matplotlib.pyplot as plt
    tf.reset_default_graph()
    try:
        tf.keras.backend.clear_session()
    except:
        pass

    print("Graph and Keras Backend reset.")
    tf.set_random_seed(1234)
    np.random.seed(1234)

    sess_config = tf.ConfigProto()
    sess_config.gpu_options.allow_growth = True
    sess = tf.Session(config=sess_config)
    print("Created TensorFlow session.")

    # Load data
    img_rows, img_cols, channels = 32, 32, 3
    datapath = '../cifar_data/'
    x_train_full, X_all_test, y_train_full, Y_all_test = load_data_cifar10(datapath, labels=None)
    x_train, _, y_train, _ = load_data_cifar10(datapath, labels=[0,6])

    all_labels = np.argmax(Y_all_test, axis=1)
    id_indices = np.where((all_labels == 0) | (all_labels == 6))[0]
    ood_indices = np.where((all_labels != 0) & (all_labels != 6))[0]

    x_clean = X_all_test[id_indices]
    y_clean = Y_all_test[id_indices]
    x_ood = X_all_test[ood_indices]
    y_ood = Y_all_test[ood_indices]

    # Map y_clean to 2-dim one-hot
    id_label_map = {0: 0, 6: 1}
    y_clean_labels = all_labels[id_indices]
    y_clean_2dim = np.zeros((len(y_clean_labels), 2))
    for i, label in enumerate(y_clean_labels):
        y_clean_2dim[i, id_label_map[label]] = 1.0

    print(f"ID Train: {x_train.shape[0]}, ID Test: {x_clean.shape[0]}, OOD: {x_ood.shape[0]}")

    # Load model
    x_placeholder = tf.placeholder(tf.float32, shape=(batch_size, img_rows, img_cols, channels))
    gen = load_classifier(sess, guard_name, data_name)
    y_logit_op = gen.predict(x_placeholder, softmax=False)

    # Compute logits helper
    def compute_logits_all(data_x):
        logits = []
        n_samples = data_x.shape[0]
        n_batch = int(n_samples / batch_size)
        for i in range(n_batch):
            X_batch = data_x[i*batch_size:(i+1)*batch_size]
            logits.append(sess.run(y_logit_op, feed_dict={x_placeholder: X_batch}))
        return np.concatenate(logits, 0)

    # Compute logits
    y_logit_train = compute_logits_all(x_train)
    y_logit_clean = compute_logits_all(x_clean)
    y_logit_ood = compute_logits_all(x_ood)

    #  Compute Log Probabilities
    results_train = comp_logp(y_logit_train, y_train, 'Train')
    results_clean = comp_logp(y_logit_clean, y_clean_2dim, 'ID Test')
    results_ood = comp_logp(y_logit_ood, y_ood[:, :2], 'OOD Test')

    #  Detection Rate
    plus = False
    alpha, detect_rate = search_alpha(results_clean[0], results_train[1], results_train[2], plus=plus)
    detect_rate_ood = comp_detect(results_ood[0], results_train[1], results_train[2], alpha, plus=plus)

    print(f'False Positive Rate (ID rejection): {detect_rate:.4f}')
    print(f'OOD Detection Rate: {detect_rate_ood:.4f}')

    # Visualization
    plt.figure(figsize=(10,6))
    plt.hist(results_ood[0], bins=50, density=True, alpha=0.6, label='OOD', color='red')
    plt.hist(results_clean[0], bins=50, density=True, alpha=0.6, label='ID', color='blue')
    plt.axvline(results_train[1] - alpha*results_train[2], color='k', linestyle='--', linewidth=2, label='Threshold')
    plt.xlabel('log p(x)')
    plt.ylabel('Frequency')
    plt.title('OOD vs ID Log-Likelihood Distribution')
    plt.legend()
    plt.show()

    sess.close()

# %% [markdown]
# OOD detection for GFZ

# %%
# Parameters
batch_size = 100
guard_name = 'bayes_K10_F'
data_name = 'plane_frog'
save_results = False

# run ood evaluation
OOD_logit(batch_size, guard_name, data_name, save_results)
# Out:
# Graph and Keras Backend reset.
# Created TensorFlow session.
# ID Train: 10000, ID Test: 2000, OOD: 8000
# settings:
# no_z False
# use_mean False
# fix_samples False
# attack_snapshot False
# decoder shared Conv Net of size [(4, 4, 256), (8, 8, 128), (16, 16, 64), (32, 32, 3)]
# encoder shared Conv net  network architecture: [(16, 16, 64), (8, 8, 128), (4, 4, 256)] [1000]
# ../save/plane_frog_conv_vae_F_128/
# param loaded 25
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/dispatch.py:1260: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
# loaded parameters from ../save/plane_frog_conv_vae_F_128/checkpoint_0.pkl
# use 10 samples
# Train: logp(x) = -64.787 +- 24.418, logp(x|y) = -65.059 +- 24.423
# ID Test: logp(x) = -65.922 +- 25.992, logp(x|y) = -66.204 +- 26.051
# OOD Test: logp(x) = -82.532 +- 32.550, logp(x|y) = -103.073 +- 28.333
# False Positive Rate (ID rejection): 5.0000
# OOD Detection Rate: 14.7500

# %% [markdown]
# OOD detection for GBZ

# %%
# Parameters
batch_size = 100
guard_name = 'bayes_K10_B'
data_name = 'plane_frog'
save_results = False

# run ood evaluation
OOD_logit(batch_size, guard_name, data_name, save_results)

# %% [markdown]
# OOD detection for DFZ

# %%
# Parameters
batch_size = 100
guard_name = 'bayes_K10_C'
data_name = 'plane_frog'
save_results = False

# run ood evaluation
OOD_logit(batch_size, guard_name, data_name, save_results)

# %% [markdown]
# **OOD Detection via Marginal Log-Likelihood**

# %%
def OOD_marginal(batch_size=100, guard_name='bayes_K10', data_name='plane_frog', save=False):
    import matplotlib.pyplot as plt
    tf.reset_default_graph()
    try:
        tf.keras.backend.clear_session()
    except:
        pass

    print("Graph and Keras Backend reset.")
    tf.set_random_seed(1234)
    np.random.seed(1234)

    sess_config = tf.ConfigProto()
    sess_config.gpu_options.allow_growth = True
    sess = tf.Session(config=sess_config)
    print("Created TensorFlow session.")

    # Load data
    img_rows, img_cols, channels = 32, 32, 3
    datapath = '../cifar_data/'
    x_train_full, X_all_test, y_train_full, Y_all_test = load_data_cifar10(datapath, labels=None)
    x_train, _, y_train, _ = load_data_cifar10(datapath, labels=[0,6])

    all_labels = np.argmax(Y_all_test, axis=1)
    id_indices = np.where((all_labels == 0) | (all_labels == 6))[0]
    ood_indices = np.where((all_labels != 0) & (all_labels != 6))[0]

    x_clean = X_all_test[id_indices]
    y_clean = Y_all_test[id_indices]
    x_ood = X_all_test[ood_indices]
    y_ood = Y_all_test[ood_indices]

    # Map y_clean to 2-dim one-hot
    id_label_map = {0: 0, 6: 1}
    y_clean_labels = all_labels[id_indices]
    y_clean_2dim = np.zeros((len(y_clean_labels), 2))
    for i, label in enumerate(y_clean_labels):
        y_clean_2dim[i, id_label_map[label]] = 1.0

    print(f"ID Train: {x_train.shape[0]}, ID Test: {x_clean.shape[0]}, OOD: {x_ood.shape[0]}")

    # Load model
    x_placeholder = tf.placeholder(tf.float32, shape=(batch_size, img_rows, img_cols, channels))
    gen = load_classifier(sess, guard_name, data_name)
    y_logit_op = gen.predict(x_placeholder, softmax=False)

    # Compute logits helper
    def compute_logits_all(data_x):
        logits = []
        n_samples = data_x.shape[0]
        n_batch = int(n_samples / batch_size)
        for i in range(n_batch):
            X_batch = data_x[i*batch_size:(i+1)*batch_size]
            logits.append(sess.run(y_logit_op, feed_dict={x_placeholder: X_batch}))
        return np.concatenate(logits, 0)

    # Compute logits
    y_logit_train = compute_logits_all(x_train)
    y_logit_clean = compute_logits_all(x_clean)
    y_logit_ood = compute_logits_all(x_ood)

    # Compute marginal log-probabilities
    results_train = comp_logp(y_logit_train, y_train, 'Train')
    results_clean = comp_logp(y_logit_clean, y_clean_2dim, 'ID Test')
    results_ood = comp_logp(y_logit_ood, y_ood[:, :2], 'OOD Test')

    # Detection Rate based on marginal log-likelihood
    # For marginal likelihood, OOD usually has low logp(x)
    plus = False
    alpha, fp_rate = search_alpha(results_clean[0], results_train[1], results_train[2], plus=plus)
    tp_rate_ood = comp_detect(results_ood[0], results_train[1], results_train[2], alpha, plus=plus)

    print(f'False Positive Rate (ID rejection, marginal): {fp_rate:.4f}')
    print(f'OOD Detection Rate (marginal): {tp_rate_ood:.4f}')

    # Visualization
    plt.figure(figsize=(10,6))
    plt.hist(results_ood[0], bins=50, density=True, alpha=0.6, label='OOD', color='red')
    plt.hist(results_clean[0], bins=50, density=True, alpha=0.6, label='ID', color='blue')
    plt.axvline(results_train[1] - alpha*results_train[2], color='k', linestyle='--', linewidth=2, label='Threshold')
    plt.xlabel('log p(x) (marginal)')
    plt.ylabel('Frequency')
    plt.title('OOD vs ID Log-Likelihood (Marginal)')
    plt.legend()
    plt.show()

    sess.close()

# %% [markdown]
# OOD for GFZ

# %%
# Parameters
batch_size = 100
guard_name = 'bayes_K10_F'
data_name = 'plane_frog'
save_results = False

OOD_marginal(batch_size, guard_name, data_name, save_results)
# Out:
# Graph and Keras Backend reset.
# Created TensorFlow session.
# ID Train: 10000, ID Test: 2000, OOD: 8000
# settings:
# no_z False
# use_mean False
# fix_samples False
# attack_snapshot False
# decoder shared Conv Net of size [(4, 4, 256), (8, 8, 128), (16, 16, 64), (32, 32, 3)]
# encoder shared Conv net  network architecture: [(16, 16, 64), (8, 8, 128), (4, 4, 256)] [1000]
# ../save/plane_frog_conv_vae_F_128/
# param loaded 25
# loaded parameters from ../save/plane_frog_conv_vae_F_128/checkpoint_0.pkl
# use 10 samples
# Train: logp(x) = -64.787 +- 24.418, logp(x|y) = -65.059 +- 24.423
# ID Test: logp(x) = -65.922 +- 25.992, logp(x|y) = -66.204 +- 26.051
# OOD Test: logp(x) = -82.532 +- 32.550, logp(x|y) = -103.073 +- 28.333
# False Positive Rate (ID rejection, marginal): 5.0000
# OOD Detection Rate (marginal): 14.7375

# %% [markdown]
# OOD for GBZ

# %%
# Parameters
batch_size = 100
guard_name = 'bayes_K10_B'
data_name = 'plane_frog'
save_results = False

OOD_marginal(batch_size, guard_name, data_name, save_results)

# %% [markdown]
# OOD for DFZ

# %%
# Parameters
batch_size = 100
guard_name = 'bayes_K10_C'
data_name = 'plane_frog'
save_results = False

OOD_marginal(batch_size, guard_name, data_name, save_results)

# %% [markdown]
# **OOD Detection via Latent-Space KL Divergence**

# %%
import numpy as np
import os
import pickle
import tensorflow.compat.v1 as tf

# Configure TF for legacy v1 behavior
tf.disable_v2_behavior()

def OOD_kl(batch_size=100, guard_name='bayes_K10_C', data_name='plane_frog', save=False):
    # Reset graph
    tf.reset_default_graph()
    try:
        tf.keras.backend.clear_session()
    except:
        pass
    print("Graph and Keras backend reset.")

    # Create session
    sess_config = tf.ConfigProto()
    sess_config.gpu_options.allow_growth = True
    sess = tf.Session(config=sess_config)
    tf.set_random_seed(1234)
    np.random.seed(1234)
    print("TF1 session created.")

    # Load data
    datapath = '../cifar_data/'
    x_train_full, X_all_test, y_train_full, Y_all_test = load_data_cifar10(datapath, labels=None)

    id_labels = [0, 6]  # Plane/Frog
    all_labels = np.argmax(Y_all_test, axis=1)
    id_indices = np.where((all_labels == id_labels[0]) | (all_labels == id_labels[1]))[0]
    ood_indices = np.where((all_labels != id_labels[0]) & (all_labels != id_labels[1]))[0]

    x_train, _, _, _ = load_data_cifar10(datapath, labels=id_labels)
    x_clean = X_all_test[id_indices]
    x_ood = X_all_test[ood_indices]

    print(f'ID train: {x_train.shape[0]}, ID test: {x_clean.shape[0]}, OOD test: {x_ood.shape[0]}')

    # Load classifier
    gen = load_classifier(sess, guard_name, data_name)  # use your TF1 sess here
    enc_conv, enc_mlp = gen.enc  # enc_conv and enc_mlp
    dimZ = 128  # latent dim used during VAE training

    # Initialize all variables to avoid "FailedPreconditionError"
    sess.run(tf.global_variables_initializer())
    print("All TF1 variables initialized.")

    # KL Divergence
    def compute_kl_all(data_x):
        kl_scores = []
        n_samples = data_x.shape[0]
        n_batch = int(np.ceil(n_samples / batch_size))

        for i in range(n_batch):
            X_batch = data_x[i*batch_size:(i+1)*batch_size]
            X_batch = X_batch.astype(np.float32)
            N = X_batch.shape[0]

            # Compute conv features
            fea = sess.run(enc_conv(X_batch))

            # Compute mean and logvar (pass dummy y if required)
            y_dummy = np.zeros((N, 2), dtype=np.float32)
  # 2 classes for Plane/Frog, adjust if needed
            mean_z, logvar_z = sess.run(enc_mlp(fea, y_dummy))

            kl = 0.5 * np.sum(np.exp(logvar_z) + mean_z**2 - 1. - logvar_z, axis=1)
            kl_scores.append(kl)

        return np.concatenate(kl_scores, 0)

    print("Computing KL for training set...")
    kl_train = compute_kl_all(x_train)
    kl_mean = np.mean(kl_train)
    kl_std = np.std(kl_train)
    print(f"Train KL: mean={kl_mean:.3f}, std={kl_std:.3f}")

    print("Computing KL for ID test set...")
    kl_clean = compute_kl_all(x_clean)
    print("Computing KL for OOD test set...")
    kl_ood = compute_kl_all(x_ood)

    # Detection thresholds
    def comp_detect(x, x_mean, x_std, alpha, plus=True):
        if plus:
            return np.mean(x > x_mean + alpha * x_std) * 100
        else:
            return np.mean(x < x_mean - alpha * x_std) * 100

    def search_alpha(x, x_mean, x_std, target_rate=5.0, plus=True):
        alpha_min, alpha_max, alpha_now = 0.0, 3.0, 1.5
        detect_rate = comp_detect(x, x_mean, x_std, alpha_now, plus)
        T = 0
        while np.abs(detect_rate - target_rate) > 0.01 and T < 20:
            if detect_rate > target_rate:
                alpha_min = alpha_now
            else:
                alpha_max = alpha_now
            alpha_now = 0.5 * (alpha_min + alpha_max)
            detect_rate = comp_detect(x, x_mean, x_std, alpha_now, plus)
            T += 1
        return alpha_now, detect_rate

    alpha, fp_rate = search_alpha(kl_clean, kl_mean, kl_std, plus=True)
    tp_rate = comp_detect(kl_ood, kl_mean, kl_std, alpha, plus=True)

    print(f"False Positive Rate (ID rejected): {fp_rate:.3f}%")
    print(f"True Positive Rate (OOD detected): {tp_rate:.3f}%")

    results = {'FP_KL': fp_rate, 'TP_KL_OOD': tp_rate}

    # Save results
    if save:
        path = f'detection_results/{guard_name}/'
        os.makedirs(path, exist_ok=True)
        filename = path + f'{data_name}_{guard_name}_OOD_KL.pkl'
        with open(filename, 'wb') as f:
            pickle.dump(results, f)
        print(f"Results saved at {filename}")
    #  Visualization

    plt.figure(figsize=(10, 6))
    plt.hist(kl_ood, bins=50, density=True, alpha=0.6, label='OOD', color='red')
    plt.hist(kl_clean, bins=50, density=True, alpha=0.6, label='ID', color='blue')
    threshold = kl_mean + alpha * kl_std
    plt.axvline(threshold, color='k', linestyle='--', linewidth=2, label='Threshold')

    plt.xlabel('KL Divergence')
    plt.ylabel('Frequency')
    plt.title('OOD vs ID KL Divergence Distribution')
    plt.legend()
    plt.show()


    sess.close()
    return results

# %% [markdown]
# OOD detection for GFZ

# %%
OOD_kl(batch_size=100, guard_name='bayes_K10_F', data_name='plane_frog', save=False)
# Out:
# Graph and Keras backend reset.
# TF1 session created.
# ID train: 10000, ID test: 2000, OOD test: 8000
# settings:
# no_z False
# use_mean False
# fix_samples False
# attack_snapshot False
# decoder shared Conv Net of size [(4, 4, 256), (8, 8, 128), (16, 16, 64), (32, 32, 3)]
# encoder shared Conv net  network architecture: [(16, 16, 64), (8, 8, 128), (4, 4, 256)] [1000]
# ../save/plane_frog_conv_vae_F_128/
# param loaded 25
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# loaded parameters from ../save/plane_frog_conv_vae_F_128/checkpoint_0.pkl
# use 10 samples
# All TF1 variables initialized.
# Computing KL for training set...
# Train KL: mean=0.033, std=0.016
# Computing KL for ID test set...
# Computing KL for OOD test set...
# False Positive Rate (ID rejected): 5.000%
# True Positive Rate (OOD detected): 1.613%
# {'FP_KL': np.float64(5.0), 'TP_KL_OOD': np.float64(1.6125)}

# %% [markdown]
# OOD detection for GBZ

# %%
OOD_kl(batch_size=100, guard_name='bayes_K10_B', data_name='plane_frog', save=False)

# %% [markdown]
# OOD detection for DFZ

# %%
OOD_kl(batch_size=100, guard_name='bayes_K10_C', data_name='plane_frog', save=False)
